# %% [markdown]
# # Visualize networks

# %%
# path to where the graphs are stored
mainpath = "c:/Frederik/Afstuderen/Results/test14/results/"

# path where centrality measure rankings are stored
analysispath = "{}analysis/".format(path)
# export path
exportpath = "{}visualization/".format(path)

# how many nodes to show in network plot
lat_names = 100
# set if you want the colors of the nodes to represent nametypes to true
# otherwise the color of the node represent the centrality of the node
nametypeiscolor = True

# %% [markdown]
# ## Import and open files

# %%
# %matplotlib inline
import networkx as nx
import os
import re
import matplotlib.pyplot as plt
import numpy as np
import csv
import collections
import forceatlas

if not os.path.exists(exportpath):
    os.makedirs(exportpath)

graphs = []

for folder in os.listdir(mainpath):
    path = mainpath + folder + "/"
    
    for file in os.listdir(path):
        if file.endswith(".gexf"):
            match = re.search(r'Bible_([\w]+)\.gexf', file)
            
            if match is not None:
                graphname = "{}_{}".format(folder, match.group(1))
                graph = nx.read_gexf(path+file, relabel=True)
                graphs.append([graphname, graph])
                print("Imported {}".format(file))
# Out:
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_I.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_I.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_I.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Samuel_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_I.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_I.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Jesaia.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf
# Imported Bible_Chronica_II.gexf
# Imported Bible_Reges_II.gexf

# %% [markdown]
# ## Latitudinal plot

# %%
def nametype_color(nametype):
    return {
        '': 'k',
        'pers': 'r',
        'gens': 'g',
        'topo': 'b',
    }.get(nametype, 'w')

# %% [markdown]
# ### Graphs with centrality measures

# %%
for graphlist in graphs:
    graphname = graphlist[0]
    graph = graphlist[1]
    
    # get centrality data from network_analysis to show as colors and sizes,
    # and only show the nodes with the highest centrality rating
    colors = []
    sizes = []
    selectednodes = []

    for counter, node in enumerate(graph):
        
        selectednodes.append(node)
        if nametypeiscolor:
            colors.append(nametype_color(graph.node[node]['nametype']))

        if counter == lat_names-1:
            break

    # get graph and create positions
    thisgraph = graph.subgraph(selectednodes)
    thisgraphpos = forceatlas.forceatlas2_layout(thisgraph)

    # draw graph
    plt.figure(1,figsize=(12,12))

    cmap=plt.cm.jet
    vmin = min(colors)
    vmax = max(colors)

    nx.draw(thisgraph, pos=thisgraphpos, nodelist=selectednodes,
                    node_color=colors, with_labels=True,
                    width=0.2, alpha=0.5, cmap=cmap, vmin=vmin, vmax=vmax)

    if not nametypeiscolor:
        sm = plt.cm.ScalarMappable(cmap=cmap, norm=plt.normalize(vmin=vmin, vmax=vmax))
        sm._A = []
        plt.colorbar(sm)

    # draw edge labels
    edgelabels = {}
    for a, b in thisgraph.edges():
        edgelabels[(a, b)] = str(thisgraph.get_edge_data(a, b, {"weight":0})["weight"])

    nx.draw_networkx_edge_labels(thisgraph, pos=thisgraphpos, edge_labels=edgelabels)

    # save as png
    savepath = "{}{}.png".format(exportpath, graphname)
    plt.savefig(savepath)
    print("Saved graph to {}".format(savepath))
    plt.close()
# Out:
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/001_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/001_Samuel_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/002_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/002_Samuel_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/003_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/003_Samuel_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/004_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/004_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/005_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/005_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/006_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/006_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/007_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/007_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/008_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/008_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/009_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/009_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/010_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/010_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/011_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/011_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/012_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/012_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/013_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/013_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/014_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/014_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/015_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/015_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/016_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/016_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/017_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/017_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/018_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/018_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/019_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/019_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/021_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/021_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/022_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/022_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/023_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/023_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/024_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/024_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/025_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/025_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/026_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/026_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/027_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/027_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/028_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/028_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/029_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/029_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/030_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/030_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/031_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/031_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/032_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/032_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/033_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/033_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/034_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/034_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/035_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/035_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/036_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/036_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/037_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/037_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/038_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/038_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/039_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/039_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/040_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/040_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/041_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/041_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/042_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/042_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/043_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/043_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/044_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/044_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/045_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/045_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/046_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/046_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/047_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/047_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/048_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/048_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/049_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/049_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/050_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/050_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/051_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/051_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/052_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/052_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/053_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/053_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/054_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/054_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/055_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/055_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/056_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/056_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/057_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/057_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/058_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/058_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/059_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/059_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/060_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/060_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/061_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/061_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/062_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/062_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/063_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/063_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/064_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/064_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/065_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/065_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/066_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/066_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/067_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/067_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/068_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/068_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/069_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/069_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/070_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/070_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/071_Jesaia.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/071_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/072_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/072_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/073_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/073_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/074_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/074_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/075_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/075_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/076_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/076_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/077_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/077_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/078_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/078_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/079_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/079_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/080_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/080_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/081_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/081_Reges_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/082_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/082_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/083_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/083_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/084_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/084_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/085_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/085_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/086_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/086_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/087_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/087_Samuel_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/088_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/089_Chronica_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/089_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/090_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/090_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/091_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/091_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/092_Chronica_II.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/092_Reges_I.png
# Saved graph to c:/Frederik/Afstuderen/Results/test14/results/visualization/093_Chronica_II.png
